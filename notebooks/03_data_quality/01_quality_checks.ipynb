# %%
import sys

SRC_PATH = "/Workspace/Users/gbpatil2002@gmail.com/nyc-hvfhv-data-platform/src"

if SRC_PATH not in sys.path:
    sys.path.append(SRC_PATH)

# %%
from data_quality.quality_checks import run_data_quality_checks

# %%
import importlib
import data_quality.quality_checks

importlib.reload(data_quality.quality_checks)

from data_quality.quality_checks import run_data_quality_checks

# %%
results = run_data_quality_checks(
    spark,
    "2026-05",
    "workspace.default.silver_hvfhv_trips",
    "workspace.default.fact_trip",
    "workspace.default.gold_daily_provider_metrics",
    "workspace.default.gold_location_metrics",
    "workspace.default.gold_shared_ride_metrics"
)
